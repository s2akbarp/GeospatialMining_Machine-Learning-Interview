# %% [markdown]
# # Here are some fundamental Python coding problems to strengthen your programming skills:
#
#
# <details>
# <summary><span style="color:red">Basic Python Coding Problems </span></summary>
#
#
# 1. **Sum of Squares of First n Natural Numbers:** Calculate the sum of squares from 1 to n.
# 2. **Sum of First n Odd Numbers:** Find the sum of the first n odd numbers.
# 3. **Sum of First n Even Numbers:** Calculate the sum of the first n even numbers.
# 4. **Generate All Possible Subsets of a Set:** Generate all subsets of a given set.
# 5. **Generate All Possible Permutations of a List:** Generate all permutations of elements in a list.
# 6. **Binary Search Algorithm:** Implement the binary search algorithm to find an element in a sorted list.
# 7. **Merge Sort Algorithm:** Implement the merge sort algorithm for sorting a list.
# 8. **Quick Sort Algorithm:** Implement the quick sort algorithm for efficient sorting.
# 9. **Heap Sort Algorithm:** Implement the heap sort algorithm using a heap data structure.
# 10. **Bubble Sort Algorithm:** Implement the bubble sort algorithm for simple sorting.
# 11. **Insertion Sort Algorithm:** Implement the insertion sort algorithm for sorting.
# 12. **Selection Sort Algorithm:** Implement the selection sort algorithm for sorting.
# 13. **Longest Common Subsequence of Two Strings:** Find the longest subsequence common to two strings.
# 14. **Longest Increasing Subsequence in a List:** Find the longest increasing subsequence in a list of numbers.
# 15. **Longest Decreasing Subsequence in a List:** Find the longest decreasing subsequence in a list of numbers.
# 16. **Depth-First Search (DFS) Algorithm:** Implement DFS for traversing or searching in graphs or trees.
# 17. **Breadth-First Search (BFS) Algorithm:** Implement BFS for traversing or searching in graphs or trees.
# 18. **Shortest Path Using Dijkstra's Algorithm:** Find the shortest path in a graph using Dijkstra's algorithm.
# 19. **Shortest Path Using Bellman-Ford Algorithm:** Find the shortest path in a graph using the Bellman-Ford algorithm.
# 20. **Floyd-Warshall Algorithm:** Implement the Floyd-Warshall algorithm for finding shortest paths in a weighted graph.
# 21. **Minimum Spanning Tree Using Kruskal's Algorithm:** Find the minimum spanning tree using Kruskal's algorithm.
# 22. **Minimum Spanning Tree Using Prim's Algorithm:** Find the minimum spanning tree using Prim's algorithm.
# 23. **Ford-Fulkerson Algorithm for Maximum Flow:** Implement the Ford-Fulkerson algorithm for finding maximum flow in a network.
# 24. **Edmonds-Karp Algorithm for Maximum Flow:** Implement the Edmonds-Karp algorithm for finding maximum flow in a network.
# 25. **Maximum Bipartite Matching in a Graph:** Implement an algorithm to find the maximum bipartite matching in a graph.
# 26. **Hungarian Algorithm for Assignment Problems:** Implement the Hungarian algorithm to solve assignment problems.
# 27. **Gale-Shapley Algorithm for Stable Marriage:** Implement the Gale-Shapley algorithm for stable matching.
# 28. **Knapsack Problem Using Dynamic Programming:** Solve the knapsack problem using dynamic programming.
# 29. **Coin Change Problem Using Dynamic Programming:** Solve the coin change problem using dynamic programming.
# 30. **Subset Sum Problem Using Dynamic Programming:** Solve the subset sum problem using dynamic programming.
# 31. **Rod Cutting Problem Using Dynamic Programming:** Solve the rod cutting problem using dynamic programming.
# 32. **Longest Palindrome Subsequence Using Dynamic Programming:** Find the longest palindrome subsequence in a string using dynamic programming.
# 33. **Sliding Window Maximum Algorithm:** Implement the sliding window maximum algorithm efficiently.
# 34. **K-Nearest Neighbors (KNN) Algorithm:** Implement the KNN algorithm for classification or regression.
# 35. **K-Means Clustering Algorithm:** Implement the K-Means clustering algorithm for unsupervised learning.
# 36. **Apriori Algorithm for Association Rule Mining:** Implement the Apriori algorithm to find frequent itemsets.
# 37. **FP-growth Algorithm for Frequent Pattern Mining:** Implement the FP-growth algorithm for efficient mining of frequent patterns.
# 38. **PageRank Algorithm for Ranking Web Pages:** Implement the PageRank algorithm to rank web pages.
# 39. **Collaborative Filtering Algorithm for Recommendation Systems:** Implement collaborative filtering for recommending items.
# 40. **Singular Value Decomposition (SVD) Algorithm:** Implement the SVD algorithm for matrix factorization.
# 41. **Principal Component Analysis (PCA) Algorithm:** Implement PCA for dimensionality reduction.
# 42. **Linear Regression Algorithm:** Implement linear regression for predicting continuous values.
# 43. **Logistic Regression Algorithm:** Implement logistic regression for binary classification.
# 44. **Support Vector Machine (SVM) Algorithm:** Implement SVM for classification and regression tasks.
# 45. **Decision Tree Algorithm:** Implement decision tree for classification and regression.
# 46. **Random Forest Algorithm:** Implement random forest for ensemble learning.
# 47. **Gradient Boosting Algorithm:** Implement gradient boosting for boosting ensemble models.
# 48. **XGBoost Algorithm:** Implement XGBoost for optimized gradient boosting.
# 49. **K-means++ Algorithm:** Implement K-means++ for improved initialization in K-means clustering.
# 50. **DBSCAN Algorithm:** Implement DBSCAN for density-based clustering.
#
# </details>
#
#
#
# <details>
# <summary><span style="color:green"> Python Proficiency </span></summary>
#
# 1. **Write a function to find the maximum of three numbers.**
#
# 2. **Write a function to sum all the numbers in a list.**
#
# 3. **Write a function to multiply all the numbers in a list.**
#
# 4. **Write a function to reverse a string.**
#
# 5. **Write a function to check whether a number is in a given range.**
#
# 6. **Write a function to count the number of uppercase and lowercase letters in a string.**
#
# 7. **Write a function to return the unique elements from a list.**
#
# 8. **Write a function to check whether a string is a palindrome.**
#
# 9. **Write a function to compute the factorial of a number.**
#
# 10. **Write a function to generate the Fibonacci sequence up to n terms.**
#
# 11. **Write a function to find the GCD of two numbers.**
#
# 12. **Write a function to find the LCM of two numbers.**
#
# 13. **Write a function to check if a number is prime.**
#
# 14. **Write a function to generate all prime numbers up to n.**
#
# 15. **Write a function to find the second largest number in a list.**
#
# 16. **Write a function to find the mode in a list of numbers.**
#
# 17. **Write a function to remove duplicates from a list.**
#
# 18. **Write a function to check if two strings are anagrams.**
#
# 19. **Write a function to find the intersection of two lists.**
#
# 20. **Write a function to find the union of two lists.**
#
# 21. **Write a function to find the difference between two lists.**
#
# 22. **Write a function to find the symmetric difference of two lists.**
#
# 23. **Write a function to flatten a nested list.**
#
# 24. **Write a function to merge two dictionaries.**
#
# 25. **Write a function to sort a list of dictionaries by a key.**
#
# 26. **Write a function to convert a list of tuples into a dictionary.**
#
# 27. **Write a function to find the length of a list without using len().**
#
# 28. **Write a function to concatenate two lists.**
#
# 29. **Write a function to check if a list is sorted.**
#
# 30. **Write a function to rotate a list by n positions.**
#
# 31. **Write a function to find the common elements in three sorted lists.**
#
# 32. **Write a function to find the top k elements in a list.**
#
# 33. **Write a function to compute the average of a list of numbers.**
#
# 34. **Write a function to compute the median of a list of numbers.**
#
# 35. **Write a function to compute the standard deviation of a list of numbers.**
#
# 36. **Write a function to find the k-th smallest element in a list.**
#
# 37. **Write a function to find the k-th largest element in a list.**
#
# 38. **Write a function to generate random numbers within a given range.**
#
# 39. **Write a function to find the most frequent element in a list.**
#
# 40. **Write a function to remove the nth element from a list.**
#
# 41. **Write a function to convert a list to a tuple.**
#
# 42. **Write a function to convert a tuple to a list.**
#
# 43. **Write a function to find the sum of the digits of a number.**
#
# 44. **Write a function to find the product of the digits of a number.**
#
# 45. **Write a function to convert a number to binary.**
#
# 46. **Write a function to convert a number to hexadecimal.**
#
# 47. **Write a function to find the digital root of a number.**
#
# 48. **Write a function to find the prime factors of a number.**
#
# 49. **Write a function to check if a number is an Armstrong number.**
#
# 50. **Write a function to compute the nth term of an arithmetic sequence.**
#
#
#
# </details>
#
#
#
# Explore these problems to enhance your Python programming skills and understanding of fundamental algorithms!
